# %% [markdown]
# # numpy库

# %%
import numpy as np
np.__version__
# Out:
# '2.4.3'

# %% [markdown]
# ## numpy.ndarray()

# %%
np.ndarray(shape=(2,2), dtype=float, order='F') # 创建ndarray
# Out:
# array([[4.65828251e-310, 0.00000000e+000],
#        [4.65926689e-310, 4.65926698e-310]])

# %% [markdown]
# ### 创建多维数组

# %%
np.ndarray((2,), buffer = np.array([1,2,3]), offset=np.int_().itemsize, dtype = int)
# Out:
# array([2, 3])

# %% [markdown]
# ### 创建多维数组

# %% [markdown]
# ## numpy.array()

# %% [markdown]
# ## numpy.arange()
#
# ·
