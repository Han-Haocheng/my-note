# %% [markdown]
# # numpy库

# %%
import numpy as np
np.__version__
# Out:
# '2.4.3'

# %%
np.ndarray(shape=(2,2), dtype=float, order='F')
np.ndarray((2,), buffer = np.array([1,2,3]), offset=np.int_().itemsize, dtype = int)
# Out:
# array([[4.65828251e-310, 4.65926689e-310],
#        [0.00000000e+000, 4.65926698e-310]])
