# %% [markdown]
# # 第7章 用户输入输出
# ## 7.1 函数input()

# %%
input()
# Out:
# 'Hello\n'

# %%
s = input()
print(s)
# Out:
# hello

# %% [markdown]
# ### 7.1.1 编写一个清晰的程序

# %%
s = input("Please enter your name:")
print(s)
# Out:
# Mike

# %%
s = input("it's our first meetint. \n Please enter your name:")
print(s)
# Out:
# Mike

# %% [markdown]
# ### 7.1.2 获取数值输入
