# %% [markdown]
# # 第二章 变量和简单数据类型
# ## 2.1

# %%
print('hello python world')
# Out:
# hello python world

# %% [markdown]
# ## 2.2
# ### 2.2.1

# %%
message = "Hello Python World"
print(message)

message = "Hello Python World"
print(message)

message = "Hello Python Crash Course World"
print(message)
# Out:
# Hello Python World
# Hello Python World
# Hello Python Crash Course World

# %% [markdown]
# ### 2.2.2

# %%
message_123 = "Hello Python World"

# %%
123_message = "Hello Python World"
# Out:
#   Cell In[4], line 1
#     123_message = "Hello Python World"
#        ^
# SyntaxError: invalid decimal literal

# %%
help("keywords")
Name = 10
print(Name)
name = 20
print(name,Name)
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
#
# 10
# 20 10

# %% [markdown]
# ### 2.2.3

# %%
a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a
#       2 print(a)
#
# NameError: name 'a' is not defined

# %%
name = 'Tom'
name
# Out:
# 'Tom'

# %%
name,age="Tom",22
name
# Out:
# 'Tom'

# %%
age
# Out:
# 22

# %%
aa,bb=11,22
print(aa,bb)
aa,bb = bb,aa
print(aa,bb)
# Out:
# 11 22
# 22 11

# %%
name="Tom"
type(name)
type("Tom")
# Out:
# str

# %%
id(name)
# Out:
# 139792932410720

# %%
id("Tom")
# Out:
# 139792932410720

# %% [markdown]
# ### 2.2.4

# %%
a =10
id(a)
# Out:
# 139793047792272

# %%
id(10)
# Out:
# 139793047792272

# %%
del a

# %%
id(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 id(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 2.3
# ### 2.3.1

# %%
a = 123
print(type(a))
print(isinstance(a,int))
# Out:
# <class 'int'>
# True

# %%
b = 'abc'
print(type(b))
print(isinstance(b,int))
# Out:
# <class 'str'>
# False

# %%
print(type(123))
# Out:
# <class 'int'>

# %%
print(type(1.23))
# Out:
# <class 'float'>

# %%
print(type(3j+1))
# Out:
# <class 'complex'>

# %%
print(type("Hello world"))
# Out:
# <class 'str'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type([1,2,3]))
# Out:
# <class 'list'>

# %%
print(type((1,2,3)))
# Out:
# <class 'tuple'>

# %%
print(type({"name":"Jane","age":"18"}))
# Out:
# <class 'dict'>

# %%
print(type(set([1,2,3])))
# Out:
# <class 'set'>

# %% [markdown]
# ### 2.3.2

# %%
print(4**1000)
print(type(4**1000))
# Out:
# ...
# <class 'int'>

# %%
0.2+0.1
# Out:
# 0.30000000000000004

# %%
3*0.1
# Out:
# 0.30000000000000004

# %%
a=12.345
print(int(a))
# Out:
# 12

# %%
b=123
print(float(b))
# Out:
# 123.0

# %%
a=12.34
b=complex(a)
print(b)
print(b.real,b.imag)
# Out:
# (12.34+0j)
# 12.34 0.0

# %%
a=10
b=20
print(complex(a,b))
# Out:
# (10+20j)

# %%
x=-12.3
print(abs(x))
y=12.3
print(abs(y))
# Out:
# 12.3
# 12.3

# %%
x=-12.3
y=12.3
print(min(x,y,100))
print(max(x,y,100))
# Out:
# -12.3
# 100

# %%
x=3
y=5
print(pow(x,y))
print(pow(y,x))
# Out:
# 243
# 125

# %%
x=3.1415926
print(round(x,3))
# Out:
# 3.142

# %% [markdown]
# ### 2.3.3

# %%
print('hello python world')
print("hello python world")
a = "hello python world"
print(a)
# Out:
# hello python world
# hello python world
# hello python world

# %%
print('I'm a student')')
# Out:
#   Cell In[41], line 1
#     print('I'm a student')
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("I'm a student")
# Out:
# I'm a student

# %%
print("python")
print("\tpython")
# Out:
# python
# 	python

# %%
print("Languages:\nPython\nC\nJava")
# Out:
# Languages:
# Python
# C
# Java

# %%
print("Languages:\n\tPython\n\tC\n\tJava")
# Out:
# Languages:
# 	Python
# 	C
# 	Java

# %%
print("Ru\noob")
# Out:
# Ru
# oob

# %%
print(r"Ru\noob")
# Out:
# Ru\noob

# %%
hi='''hi
hello python world'''
hi
# Out:
# 'hi\nhello python world'

# %%
hi='''hi
hello python world'''
print(hi)
# Out:
# hi
# hello python world

# %%
u'Hello World!'
# Out:
# 'Hello World!'

# %%
u'Hello\u0020World'
# Out:
# 'Hello World'

# %%
name="abcdfsdfsdf"
name[1:4]
# Out:
# 'bcd'

# %%
name[:]
# Out:
# 'abcdfsdfsdf'

# %%
name[::2]
# Out:
# 'acfdsf'

# %%
name[0:]
# Out:
# 'abcdfsdfsdf'

# %%
name[:-1]
# Out:
# 'abcdfsdfsd'

# %%
str1='Hello World'
str1[0] = 'h'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 str1='Hello World'
# ----> 2 str1[0] = 'h'
#
# TypeError: 'str' object does not support item assignment

# %%
var1='Hello World'
var2 = "更新字符串："+var1[:6]+"Runoob!"
print(var2)
# Out:
# 更新字符串：Hello Runoob!

# %%
first_name = "Li"
last_name="lianjie"
full_name = first_name +" "+ last_name
print("Hello,"+full_name+"!")
message = "Hello,"+full_name.title()+"!"
print(message)
# Out:
# Hello,Li lianjie!
# Hello,Li Lianjie!

# %%
b = '100'
c= "200"
d="b+c= %s"%(b+c)

# %%
Temp = "我叫 %s,今年 %d 岁"%("心叶",7)
print(Temp)
# Out:
# 我叫 心叶,今年 7 岁

# %%
age = 23
message = "Happy "+age+"rd Birthday"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 age = 23
# ----> 2 message = "Happy "+age+"rd Birthday"
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 23
message = "Happy "+str(age)+"rd Birthday"
print(message)
# Out:
# Happy 23rd Birthday

# %%
str1 = "Hello World"
len(str1)
# Out:
# 11

# %%
str1[len(str1)-1]
# Out:
# 'd'

# %%
print(str1.lower())
str1.title()
# Out:
# hello world
# 'Hello World'

# %%
print(str1)
str1.capitalize()
# Out:
# Hello World
# 'Hello world'

# %%
print(str1)
str1.lower()
# Out:
# Hello World
# 'hello world'

# %%
print(str1)
str1.upper()
# Out:
# Hello World
# 'HELLO WORLD'

# %%
str1='ABC'
user_str = "Abc"
print(user_str.upper())
user_str.upper() == str1
# Out:
# ABC
# True

# %%
my_str = "Hello world zyj everyone in the world"
my_str.find("zyj")
# Out:
# 12

# %%
my_str = "Hello world zyj everyone in the world"
my_str.find("lw")
# Out:
# -1

# %%
my_str = "Hello world zyj everyone in the world"
my_str.rfind("world")
# Out:
# 32

# %%
my_str = "Hello world zyj everyone in the world"
my_str.index("world")
# Out:
# 6

# %%
my_str = "Hello world zyj everyone in the world"
my_str.index("lw")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 2
#       1 my_str = "Hello world zyj everyone in the world"
# ----> 2 my_str.index("lw")
#
# ValueError: substring not found

# %%
my_str = "Hello world zyj everyone in the world"
my_str.rindex("world")
# Out:
# 32

# %%
str1="python"
str2="python      "
print(str1,len(str1))
print(str2,len(str2))
str1==str2,str1==str2.strip()
# Out:
# python 6
# python       12
# (False, True)

# %%
name="Tom"
print(name.ljust(10))
print(name.center(10))
print(name.rjust(10))
# Out:
# Tom
#    Tom
#        Tom

# %%
name1 = name.ljust(10)
print(name1,len(name1),name1.lstrip(),len(name1.lstrip()))
name2 = name.center(10)
print(name2,len(name2),name2.strip(),len(name2.strip()))
name3 = name.rjust(10)
print(name3,len(name3),name3.rstrip(),len(name3.rstrip()))
# Out:
# Tom        10 Tom        10
#    Tom     10 Tom 3
#        Tom 10        Tom 10

# %%
str1="Python is an powerful programming language."
str1.count("o")
# Out:
# 3

# %%
str1="Python is an powerful programming language."
print(str1.replace("o","e"))
print(str1.replace("o","e",2))
# Out:
# Pythen is an pewerful pregramming language.
# Pythen is an pewerful programming language.

# %% [markdown]
# ## 2.4
# ### 2.4.2

# %%
x=10
y=20
print("x+y=",x+y,
      "x-y=",x-y,
      "x*y=",x*y,
      "y/x=",y/x,
      "y%x=",y%x)
# Out:
# x+y= 30 x-y= -10 x*y= 200 y/x= 2.0 y%x= 0

# %%
x=10.0
y=20
print("x+y=",x+y,
      "x-y=",x-y,
      "x*y=",x*y,
      "y/x=",y/x,
      "y%x=",y%x)
# Out:
# x+y= 30.0 x-y= -10.0 x*y= 200.0 y/x= 2.0 y%x= 0.0

# %%
x=10.0
y=25
print("x**y=",x**y,
      "x//y=",x//y,
      "y//x=",y//x,
      "-y//x=",-y//x)
# Out:
# x**y= 1e+25 x//y= 0.0 y//x= 2.0 -y//x= -3.0

# %% [markdown]
# ### 2.4.3

# %%
x=10
y=25
print("x==y=",x==y,
      "  x!=y=",x!=y,
      "  y>x=",y>x,
      "  y<=x=",y<=x)
print("(x==y)+1=",(x==y)+1,
      "(x!=y)+1=",(x!=y)+1)
# Out:
# x==y= False   x!=y= True   y>x= True   y<=x= False
# (x==y)+1= 1 (x!=y)+1= 2

# %% [markdown]
# ### 2.4.4

# %%
a=60
b=13
print("a&b=",a&b,
      "   a|b=",a|b,
      "   a^b=",a^b,
      "   ~a=",~a,
      "   a<<2=",a<<2,
      "   a>>2=",a>>2)
# Out:
# a&b= 12    a|b= 61    a^b= 49    ~a= -61    a<<2= 240    a>>2= 15

# %% [markdown]
# ### 2.4.5

# %%
a = True
b = False
print(a and b,a or b,not a)
# Out:
# False True False

# %%
a=10
b=20
print("a and b=",a and b,
      "   a or b=",a or b,
      "   not a=",not a)
# Out:
# a and b= 20    a or b= 10    not a= False

# %% [markdown]
# ### 2.4.7

# %%
a=10
b=[10,20,30]
c=50
print("a in b=",a in b,
      "  c in b=",c in b)
# Out:
# a in b= True   c in b= False

# %% [markdown]
# ### 2.4.8

# %%
a=[1,2,3]
b=a
print("a is b=",a is b,"a == b=",a == b)
b=a[:]
print("a is b=",a is b,"a == b=",a == b)
# Out:
# a is b= True a == b= True
# a is b= False a == b= True

# %% [markdown]
# ## 2.5

# %%
# 向大家问好
print("Hello Python World!")
# Out:
# Hello Python World!

# %% [markdown]
# ### 2.5.2

# %%
print("Hello Python World!") # 向大家问好
# Out:
# Hello Python World!

# %% [markdown]
# ### 2.5.3

# %%
'''
这是一个多行注释
在多行注释之间，可以写很多的内容......
'''
print("Hello Python World!")
# Out:
# Hello Python World!
